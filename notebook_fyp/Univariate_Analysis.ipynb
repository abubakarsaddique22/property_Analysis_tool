# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# display max row and columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df=pd.read_csv('/content/data_version_2_update.csv')
df.head()
# Out:
#    House Number        City         House Type  Parking Spaces  Bedrooms  \
# 0      48022756  Rawalpindi  Rawalpindi Houses             NaN       5.0
# 1      51560745  Rawalpindi  Rawalpindi Houses             NaN       5.0
# 2      51815448  Rawalpindi  Rawalpindi Houses             NaN       5.0
# 3      52061409  Rawalpindi  Rawalpindi Houses             1.0       3.0
# 4      52010487  Rawalpindi  Rawalpindi Houses             3.0       6.0
#
#    Bathrooms  Servant Quarters  Kitchens  Store Rooms  price    Purpose  \
# 0        6.0               1.0       2.0          0.0   7.50   For Sale
# 1        6.0               1.0       2.0          0.0   3.75   For Sale
# 2        6.0               1.0       2.0          0.0   4.25   For Sale
# 3        3.0               0.0       1.0          0.0   1.50   For Sale
# 4        6.0               1.0       2.0          1.0   4.75   For Sale
#
#                                        Location  Age Possession    area  \
# ...

# %% [markdown]
# ### columns Types
# - **Numerical** - House Number,Parking Spaces,Bedrooms, Bathrooms,
# Servant Quarters,Kitchens,Store Rooms,price,Area,price_per_sqft
# - **Categorical** - City,House Type,purpose,Age Possession,province
# - **Mixed** - colony,society,Location

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## categorical columns

# %%
df['property Type']=df['House Type'].str.split().str.get(1)

# %%
df.drop('House Type',axis=1,inplace=True)

# %%
df['property Type'].value_counts()
# Out:
# property Type
# Houses       1228
# Flats         118
# Upper          13
# Lower           6
# Penthouse       1
# Name: count, dtype: int64

# %%
df['property Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='property Type'>

# %%
df['property Type'].isnull().sum()
# Out:
# 153

# %%
df[df['property Type'].isnull()]
# Out:
#       House Number City  Parking Spaces  Bedrooms  Bathrooms  \
# 5         42644685  NaN             2.0       3.0        3.0
# 6         52099738  NaN             3.0       2.0        2.0
# 31        45256816  NaN             1.0       3.0        3.0
# 43        52110160  NaN             NaN       NaN        NaN
# 44        52110158  NaN             NaN       1.0        1.0
# 45        52110157  NaN             NaN       1.0        1.0
# 46        52110156  NaN             NaN       1.0        1.0
# 47        52110141  NaN             NaN       1.0        1.0
# 48        52110140  NaN             NaN       1.0        1.0
# 64        52110139  NaN             NaN       1.0        1.0
# 65        52110127  NaN             NaN       NaN        NaN
# 66        52110122  NaN             NaN       1.0        1.0
# 67        52110120  NaN             NaN       1.0        1.0
# 68        52110119  NaN             NaN       1.0        1.0
# ...

# %% [markdown]
# ### observation
# - Houses majority(80%) and other like flasts,upper,lower,penthouse approxmately 20%
# - property types have `153` missing values

# %% [markdown]
# ### society

# %%
df['society'].value_counts().shape
# Out:
# (139,)

# %%
df['society'].value_counts()
# Out:
# society
# Bahria Town Rawalpindi                           408
# DHA Defence                                      269
# Bahria Town                                       85
# Park View City                                    51
# Bahria Town Karachi                               45
# Adiala Road                                       38
# Airport Housing Society                           35
# Gulistan                                          25
# Cantt                                             25
# Central Park Housing Scheme                       23
# Askari                                            22
# Paragon City                                      22
# GT Road                                           21
# Gulshan                                           20
# Gulberg                                           17
# Bahria Orchard                                    17
# Raiwind Road                                      16
# Gulshan Abad                                      16
# ...

# %%
society_counts = df['society'].value_counts()

# Frequency distribution for societies
frequency_bins = {
    "Very High (>100)": (society_counts > 100).sum(),
    "High (50-100)": ((society_counts >= 50) & (society_counts <= 100)).sum(),
    "Average (10-49)": ((society_counts >= 10) & (society_counts < 50)).sum(),
    "Low (2-9)": ((society_counts > 1) & (society_counts < 10)).sum(),
    "Very Low (1)": (society_counts == 1).sum()
}
frequency_bins
# Out:
# {'Very High (>100)': 2,
#  'High (50-100)': 2,
#  'Average (10-49)': 26,
#  'Low (2-9)': 45,
#  'Very Low (1)': 64}

# %%
# top 10 socity
df['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='society'>

# %%
df['society'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Assumption
# - we have total socity Names `139`
# - the top socity estimate `10%` but in avg and  low and very low socity estimate `90%`
#   - 'Very High (>100)': only 2 socitys have more then 100 listings,
#   -  'High (50-100)': Here 2 socity have between 50 to 100 listings,
#   - 'Average (10-49)': 26 socitys have between 10 to 48 listings,
#   -  'Low (2-9)': 45 socity have between 2 to 9 listings,
#   - 'Very Low (1)': A significant number, 64 societies, have only 1 listing.
# - there are not any missing values

# %% [markdown]
# ## colony

# %%
df['colony'].value_counts()
# Out:
# colony
# Bahria Town Phase 8                                     129
# Bahria Town                                             124
# Bahria Town Phase 8                                      92
# DHA Phase 6                                              54
# Bahria Greens                                            43
# Park View City                                           31
# DHA Phase 7                                              30
# Bahria Town Phase 3                                      30
# DHA 9 Town                                               29
# Snober City                                              27
# DHA Phase 6                                              24
# Airport Housing Society                                  23
# DHA Phase 7                                              22
# Bahria Town Phase 4                                      21
# Park View City                                           20
# ...

# %%
# Frequency distribution for sectors
colony_counts = df['colony'].value_counts()

colony_frequency_bins = {
    "Very High (>100)": (colony_counts > 100).sum(),
    "High (50-100)": ((colony_counts >= 50) & (colony_counts <= 100)).sum(),
    "Average (10-49)": ((colony_counts >= 10) & (colony_counts < 50)).sum(),
    "Low (2-9)": ((colony_counts > 1) & (colony_counts < 10)).sum(),
    "Very Low (1)": (colony_counts == 1).sum()
}

colony_frequency_bins
# Out:
# {'Very High (>100)': 2,
#  'High (50-100)': 2,
#  'Average (10-49)': 33,
#  'Low (2-9)': 109,
#  'Very Low (1)': 158}

# %%
# top 10 colonys
df['colony'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='colony'>

# %%
# check missing values
df['colony'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Observations
#
# - There are a total of 304 unique colonys in the dataset.
# - Frequency distribution of colonys:
#     - Very High (>100): 2 colonys have more than 100 listings.
#     - High (50-100): 2 colonys have between 50 to 100 listings.
#     - Average (10-49): A majority, 33 colonys, fall in this range with 10 to 49 listings each.
#     - Low (2-9): 109 colonys have between 2 to 9 listings.
#     - Very Low (1): 158 colonys with only 1 listing.
# - colony don't have any mssing values

# %% [markdown]
# ## city

# %%
df['City'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
# missing value check in city column
df['City'].isnull().sum()
# Out:
# 153

# %% [markdown]
# ## Assumption
# - we have total citys data lahroe,rawalpindi and karachi
# - city have `153` missing values

# %% [markdown]
# ## Age Possession

# %%
df['Age Possession'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Age Possession'>

# %%
# check missing values in Age Possession column
df['Age Possession'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Assumption
# - city column have `0` missing values

# %% [markdown]
# # Numerical columns

# %% [markdown]
# ### price

# %%
df['price'].describe()
# Out:
# count    1519.000000
# mean        4.926083
# std         5.647443
# min         0.260000
# 25%         1.800000
# 50%         3.150000
# 75%         6.000000
# max        58.000000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'],kde=True,bins=50,color='lightgreen')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x=df['price'],color='lightgreen')
plt.grid()

# %%
df['price'].isnull().sum()
# Out:
# 0

# %%
df['price'].describe()
# Out:
# count    1519.000000
# mean        4.926083
# std         5.647443
# min         0.260000
# 25%         1.800000
# 50%         3.150000
# 75%         6.000000
# max        58.000000
# Name: price, dtype: float64

# %% [markdown]
# - Descriptive Statistics:
#
#     - Count: There are 1,519 non-missing price entries.
#     - Mean Price: The average price is approximately 4.92 crores.
#     - Median Price: The median (or 50th percentile) price is 5.64 crores.
#     - Standard Deviation: The prices have a standard deviation of 5.64, indicating variability in the prices.
#     - Range: Prices range from a minimum of 0.26 crores to a maximum of 58 crores.
#     - IQR: The interquartile range (difference between 75th and 25th percentile) is from 1.80 crores to 6.00 crores.
#
#
# - Visualizations:
#
#     - Distribution: The histogram indicates that most properties are priced in the lower range (below 5 crores and high number between 2 to 3 crores ), with a few properties going beyond 10 crores.
#     - Box Plot: The box plot showcases the spread of the data and potential outliers. Properties priced above approximately 10 crores might be considered outliers as they lie beyond the upper whisker of the box plot.
#
#
# - Missing Values: There are not ay  missing values in the price column.

# %%
df['price'].skew(), df['price'].kurtosis()
# Out:
# (3.6394888629833417, 19.062253363660414)

# %% [markdown]
# **Skewness**: The price distribution has a skewness of approximately 3.63, indicating a positive skew. This means that the distribution tail is skewed to the right, which aligns with our observation from the histogram where most properties have prices on the lower end with a few high-priced properties.
#
# **Kurtosis**: The kurtosis value is approximately 19.06. A kurtosis value greater than 3 indicates a distribution with heavier tails and more outliers compared to a normal distribution.

# %%
# Quantile Analysis
quantiles = df['price'].quantile([0.01, 0.05, 0.95, 0.99])

quantiles
# Out:
# 0.01     0.450
# 0.05     0.739
# 0.95    15.000
# 0.99    30.820
# Name: price, dtype: float64

# %% [markdown]
# Quantile Analysis:
#
# - 1% Quantile: Only 1% of properties are priced below 0.45 crores.
# - 5% Quantile: 5% of properties are priced below 0.73 crores.
# - 95% Quantile: 95% of properties are priced below 15.0 crores.
# - 99% Quantile: 99% of properties are priced below 30.82. crores, indicating that very few properties are priced above this value.

# %%
# Identify potential outliers using IQR method
Q1 = df['price'].describe()['25%']
Q3 = df['price'].describe()['75%']
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
outliers.shape
# Out:
# (112, 18)

# %%
outliers['price'].describe()
# Out:
# count    112.000000
# mean      20.465089
# std        9.155756
# min       12.500000
# 25%       14.787500
# 50%       16.800000
# 75%       22.587500
# max       58.000000
# Name: price, dtype: float64

# %% [markdown]
# Outliers Analysis (using IQR method):
#
# - Based on the IQR method, there are 112 properties considered as outliers.
# - These outliers have an average price of approximately 20.46 crores.
# - The range for these outliers is from 12.50 crores to 58.0 crores.

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.histplot(df['price'], kde=True, bins=50, color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.histplot(np.log1p(df['price']), kde=True, bins=50, color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# np.log1p(x): This function computes the natural logarithm of 1+x.
# It's designed to provide more accurate results for values of x that are very close to zero.
#
# Using np.log1p helps in transforming the price column while ensuring that any value (including zero, if present) is handled appropriately. When we need to reverse the transformation, we can use np.expm1 which computes e^x-1

# %%
skewness = np.log1p(df['price']).skew()
kurtosis = np.log1p(df['price']).kurt()

print(skewness,kurtosis)
# Out:
# 0.6998121052118811 0.33750677435013987

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.boxplot(df['price'], color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.boxplot(np.log1p(df['price']), color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## price_per_sqft

# %%
df['price_per_sqft'].describe()
# Out:
# count     1454.000000
# mean     15291.293817
# std       6833.679597
# min        550.960000
# 25%      11559.762500
# 50%      13915.305000
# 75%      17251.115000
# max      62222.220000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(df['price_per_sqft'],kde=True,bins=50)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
df['price_per_sqft'].skew()
# Out:
# 2.1305254657194017

# %%
sns.boxplot(x=df['price_per_sqft'],color='lightgreen')
plt.grid()

# %% [markdown]
# ## Assumption
# - Most properties have a price_per_sqft ranging between approximately 10000 and 25,000.and some lower range both side like 0 to 10000 and after 25000 to go on
# - The box plot clearly shows several outliers, especially on the higher side. The interquartile range (IQR) is relatively compact

# %%
df['price_per_sqft'].isnull().sum()
# Out:
# 65

# %% [markdown]
# #### Observations
#
# - several  Outliers
# - Right Skewed `2.13`
# - 65 missing values

# %% [markdown]
# ## Bedrooms

# %%
df['Bedrooms'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Bedrooms'>

# %%
df['Bedrooms'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
df['Bedrooms'].isnull().sum()
# Out:
# 112

# %% [markdown]
# ## Bathrooms

# %%
df['Bathrooms'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Bathrooms'>

# %%
df['Bathrooms'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
df['Bathrooms'].isnull().sum()
# Out:
# 112

# %% [markdown]
# ## area

# %%
df['area'].describe()
# Out:
# count      1454.000000
# mean       3075.992435
# std        4168.405139
# min         279.000000
# 25%        1361.000000
# 50%        2277.000000
# 75%        3600.000000
# max      108900.000000
# Name: area, dtype: float64

# %%
df['area'].isnull().sum()
# Out:
# 65

# %%
sns.histplot(df['area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
sns.boxplot(df['area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='area'>

# %% [markdown]
# - Most properties have a area ranging roughly between 0 sq.ft and 10,000 sq.ft.
# - There are very few properties with a much larger area, leading to a highly right-skewed distribution.
# - The box plot confirms the presence of significant outliers on the higher side. The data's interquartile range (IQR) is relatively compact, but the "whiskers" of the box plot are stretched due to the outliers.

# %%
df.head()
# Out:
#    House Number        City  Parking Spaces  Bedrooms  Bathrooms  \
# 0      48022756  Rawalpindi             NaN       5.0        6.0
# 1      51560745  Rawalpindi             NaN       5.0        6.0
# 2      51815448  Rawalpindi             NaN       5.0        6.0
# 3      52061409  Rawalpindi             1.0       3.0        3.0
# 4      52010487  Rawalpindi             3.0       6.0        6.0
#
#    Servant Quarters  Kitchens  Store Rooms  price    Purpose  \
# 0               1.0       2.0          0.0   7.50   For Sale
# 1               1.0       2.0          0.0   3.75   For Sale
# 2               1.0       2.0          0.0   4.25   For Sale
# 3               0.0       1.0          0.0   1.50   For Sale
# 4               1.0       2.0          1.0   4.75   For Sale
#
#                                        Location  Age Possession    area  \
# 0  Bahria Town Rawalpindi, Rawalpindi, Punjab,   Relatively New  5445.0
# ...

# %%
plt.figure(figsize=(20, 12))

# Create a subplot of pie charts for each room type
for idx, room in enumerate(['Servant Quarters','Kitchens','Store Rooms'], 1):
    ax = plt.subplot(2, 3, idx)
    df[room].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, ax=ax)
    plt.title(f'Distribution of {room.title()}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    House Number        City  Parking Spaces  Bedrooms  Bathrooms  \
# 0      48022756  Rawalpindi             NaN       5.0        6.0
# 1      51560745  Rawalpindi             NaN       5.0        6.0
# 2      51815448  Rawalpindi             NaN       5.0        6.0
# 3      52061409  Rawalpindi             1.0       3.0        3.0
# 4      52010487  Rawalpindi             3.0       6.0        6.0
#
#    Servant Quarters  Kitchens  Store Rooms  price    Purpose  \
# 0               1.0       2.0          0.0   7.50   For Sale
# 1               1.0       2.0          0.0   3.75   For Sale
# 2               1.0       2.0          0.0   4.25   For Sale
# 3               0.0       1.0          0.0   1.50   For Sale
# 4               1.0       2.0          1.0   4.75   For Sale
#
#                                        Location  Age Possession    area  \
# 0  Bahria Town Rawalpindi, Rawalpindi, Punjab,   Relatively New  5445.0
# ...
